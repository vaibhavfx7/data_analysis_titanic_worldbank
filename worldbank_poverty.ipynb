# %%
import pandas as pd
d=pd.read_csv("world.csv")
x=[]
c=0
x=d["poor"]
for i in x:
    if 'Poverty headcount ratio at $1.90' in str(i):
        c+=1
        x=i.split("$")
print(c)
# Out:
# 264

# %%
import pandas as pd
import matplotlib.pyplot as plt

d=pd.read_csv("world.csv")
dic={}
l = []
for i in range(len(d)):
    if (d["poor"][i])=="Poverty gap at $1.90 a day (2011 PPP) (%)":
        if d["2011"][i] > 0.0:
            dic[d["country"][i]]=d["2011"][i]
            print(d["2011"][i])
            l.append(d['2011'][i])
dic=sorted(dic.items(),key=lambda x:x[1]) 
print(l)
plt.hist(l)
# Out:
# 0.4
# 0.3
# 0.3
# 0.1
# 19.0
# 0.9
# 3.1
# 2.0
# 0.7
# 1.8
# 14.9
# 2.4
# 0.6
# 0.7
# 0.2
# 1.8
# 0.6
# 1.8
# 0.9
# 0.6
# 16.2
# 0.2
# 3.8
# 0.8
# 0.4
# 7.0
# 0.4
# 12.6
# 2.3
# 4.3
# 0.4
# 0.9
# 0.2
# 2.3
# 20.4
# 4.9
# 4.8
# 0.5
# 0.5
# 0.5
# 5.2
# 0.1
# 0.1
# 0.1
# 13.9
# 1.1
# 0.9
# 1.4
# 0.2
# 1.6
# 0.1
# 4.0
# 12.8
# 16.7
# 1.1
# 17.8
# 0.2
# 0.2
# 15.3
# 23.2
# 15.4
# 1.5
# 4.1
# 0.1
# 5.2
# [0.4, 0.3, 0.3, 0.1, 19.0, 0.9, 3.1, 2.0, 0.7, 1.8, 14.9, 2.4, 0.6, 0.7, 0.2, 1.8, 0.6, 1.8, 0.9, 0.6, 16.2, 0.2, 3.8, 0.8, 0.4, 7.0, 0.4, 12.6, 2.3, 4.3, 0.4, 0.9, 0.2, 2.3, 20.4, 4.9, 4.8, 0.5, 0.5, 0.5, 5.2, 0.1, 0.1, 0.1, 13.9, 1.1, 0.9, 1.4, 0.2, 1.6, 0.1, 4.0, 12.8, 16.7, 1.1, 17.8, 0.2, 0.2, 15.3, 23.2, 15.4, 1.5, 4.1, 0.1, 5.2]
# (array([43.,  5.,  5.,  0.,  0.,  3.,  4.,  2.,  2.,  1.]),
#  array([ 0.1 ,  2.41,  4.72,  7.03,  9.34, 11.65, 13.96, 16.27, 18.58,
#         20.89, 23.2 ]),
#  <a list of 10 Patch objects>)

# %%
country=[]
data=[]
for i in range(len(dic)):
    country.append(dic[i][0])
    data.append(dic[i][1])
x=country
y=data

# %%
import matplotlib.pyplot as plt
plt.hist(data,bins=30)
plt.show()

# %%
plt.plot(country,data)
plt.show()

# %%
pd.read_csv("train.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
d=pd.read_csv("train.csv")
import matplotlib.pyplot as plt
d["Sex"].value_counts()
print(type(d["Sex"].value_counts()))
labels=['male','female']
plt.pie(d["Sex"].value_counts(),labels=labels)
plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %%
d=pd.read_csv("train.csv")
m=0
f=0
import matplotlib.pyplot as plt
for i in range(len(d)):
    if d["Survived"][i]==1:
        if d["Sex"][i]=="male": 
            m=m+1
        elif d["Sex"][i]=="female":    
            f=f+1
list=[m,f]            
male=m
female=f
labels=['male_survived','female_survived']
plt.pie(list,labels=labels)
plt.show()

# %%
d=pd.read_csv("train.csv")
m={}
f={}
import matplotlib.pyplot as plt
for i in range(len(d)):
    if d["Survived"][i]==1:
        if d["Sex"][i]=="male": 
            m[d["Fare"][i]]=d["Age"][i]
        elif d["Sex"][i]=="female":
            f[d["Fare"][i]]=d["Age"][i]
plt.scatter(m.values(),m.keys())
plt.show()
plt.scatter(f.values(),f.keys())
plt.show()

# %%
import math
agegroup = []
age_male = []
age_female = []

for i in range(891):
    if d['Sex'][i] == 'male':
          and d['Survived'][i] == 0:
             age_male.append(d['Age'][i])
    else:
        if math.isnan(d['Age'][i]) == False and d['Survived'][i] == 0:
            age_female.append(d['Age'][i])
            
agegroup = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70]

plt.hist(age_male, agegroup, histtype = 'bar', rwidth = 0.9)
plt.hist(age_female, agegroup, histtype = 'bar', rwidth = 0.9)
# Out:
# (array([ 5.,  6.,  4.,  7., 10., 10.,  6.,  4.,  5.,  5.,  1.,  1.,  0.,
#          0.]),
#  array([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70]),
#  <a list of 14 Patch objects>)

# %%
import math
agegroup = []
Fare_male = []
Fare_female = []

for i in range(891):
    if d['Sex'][i] == 'male':
        if math.isnan(d['Fare'][i]) == False and d['Survived'][i] == 0:
             Fare_male.append(d['Fare'][i])
    else:
        if math.isnan(d['Fare'][i]) == False and d['Survived'][i] == 0:
            Fare_female.append(d['Fare'][i])
            
Faregroup = [0, 10, 20, 30, 40, 50, 60, 70]

plt.hist(age_male, Faregroup, histtype = 'bar', rwidth = 0.9)
plt.hist(age_female, Faregroup, histtype = 'bar', rwidth = 0.9)
# Out:
# (array([26., 21., 18.,  9.,  2.,  0.,  3.]),
#  array([ 0, 10, 20, 30, 40, 50, 60, 70]),
#  <a list of 7 Patch objects>)

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
agegroup = []
class_male = []
class_female = []
cabin_male=[]
cabin_female=[]
d=pd.read_csv("train.csv")
for i in range(891):
    if d['Sex'][i] == 'male':
        if math.isnan(d['Pclass'][i]) == False and d['Survived'][i] == 0:
            class_male.append(d['Pclass'][i])
        if d['Cabin'][i]!="" and d['Survived'][i] == 0:
            cabin_male.append(d['Cabin'][i])           
    else:
        if math.isnan(d['Pclass'][i]) == False and d['Survived'][i] == 0:
            class_female.append(d['Pclass'][i])
        if d['Cabin'][i]!="" and d['Survived'][i] == 0:
            cabin_male.append(d['Cabin'][i])    
         
agegroup = [0, 5, 10]
#plt.hist(class_male,bins, histtype = 'bar', rwidth = 1)
#plt.hist(class_female,bins,histtype = 'bar', rwidth = 1)
plt.hist(cabin_male,agegroup, histtype = 'bar', rwidth = 1)
plt.hist(cabin_female,agegroup,histtype = 'bar', rwidth = 1)
# Out:
# (array([0., 0.]), array([ 0,  5, 10]), <a list of 2 Patch objects>)
